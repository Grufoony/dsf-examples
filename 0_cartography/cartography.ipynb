# %% [markdown]
# #

# %% [markdown]
# # Examples for the cartography module

# %% [markdown]
# ## Getting the cartography of a city

# %%
from dsf import cartography
import osmnx as ox
import networkx as nx

# %%
G, edges, nodes = cartography.get_cartography("Bologna, Italy", scc=True)

# %%
ox.plot_graph(nx.MultiDiGraph(G))
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
